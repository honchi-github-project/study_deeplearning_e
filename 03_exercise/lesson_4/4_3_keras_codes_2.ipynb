# %% [markdown]
# # keras

# %% [markdown]
# ## 単純パーセプトロン
# OR回路

# %%
# モジュール読み込み
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.optimizers import SGD
 
# 乱数を固定値で初期化
np.random.seed(0)

# シグモイドの単純パーセプトロン作成
model = Sequential()
model.add(Dense(input_dim=2, units=1))
model.add(Activation('sigmoid'))
model.summary()

model.compile(loss='binary_crossentropy', optimizer=SGD(lr=0.1))
 
# トレーニング用入力 X と正解データ T
X = np.array( [[0,0], [0,1], [1,0], [1,1]] )
T = np.array( [[0], [1], [1], [1]] )
 
# トレーニング
model.fit(X, T, epochs=30, batch_size=1)
 
# トレーニングの入力を流用して実際に分類
Y = model.predict_classes(X, batch_size=1)

print("TEST")
print(Y == T)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_2 (Dense)              (None, 1)                 3
# _________________________________________________________________
# activation_2 (Activation)    (None, 1)                 0
# ...
# Total params: 3
# Trainable params: 3
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 4/4 [==============================] - 0s 76ms/step - loss: 0.4352
# Epoch 2/30
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4204
# Epoch 3/30
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4079
# Epoch 4/30
# 4/4 [==============================] - 0s 1ms/step - loss: 0.3971
# Epoch 5/30
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3876
# Epoch 6/30
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3790
# Epoch 7/30
# ...

# %% [markdown]
# ----
# ### [try]
# -  np.random.seed(0)をnp.random.seed(1)に変更
# ----

# %%
# モジュール読み込み
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.optimizers import SGD
 
# 乱数を固定値で初期化
np.random.seed(1)  ## original: np.random.seed(0)

# シグモイドの単純パーセプトロン作成
model = Sequential()
model.add(Dense(input_dim=2, units=1))
model.add(Activation('sigmoid'))
model.summary()

model.compile(loss='binary_crossentropy', optimizer=SGD(lr=0.1))
 
# トレーニング用入力 X と正解データ T
X = np.array( [[0,0], [0,1], [1,0], [1,1]] )
T = np.array( [[0], [1], [1], [1]] )
 
# トレーニング
model.fit(X, T, epochs=30, batch_size=1)
 
# トレーニングの入力を流用して実際に分類
Y = model.predict_classes(X, batch_size=1)

print("TEST")
print(Y == T)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_4 (Dense)              (None, 1)                 3
# _________________________________________________________________
# activation_4 (Activation)    (None, 1)                 0
# ...
# Total params: 3
# Trainable params: 3
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 4/4 [==============================] - 0s 82ms/step - loss: 0.4976
# Epoch 2/30
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4734
# Epoch 3/30
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4528
# Epoch 4/30
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4364
# Epoch 5/30
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4231
# Epoch 6/30
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4115
# Epoch 7/30
# ...

# %% [markdown]
# ----
# ### [try]
# -  エポック数を100に変更
# ----

# %%
# モジュール読み込み
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.optimizers import SGD
 
# 乱数を固定値で初期化
np.random.seed(1)  ## original: np.random.seed(0)

# シグモイドの単純パーセプトロン作成
model = Sequential()
model.add(Dense(input_dim=2, units=1))
model.add(Activation('sigmoid'))
model.summary()

model.compile(loss='binary_crossentropy', optimizer=SGD(lr=0.1))
 
# トレーニング用入力 X と正解データ T
X = np.array( [[0,0], [0,1], [1,0], [1,1]] )
T = np.array( [[0], [1], [1], [1]] )
 
# トレーニング
model.fit(X, T, epochs=100, batch_size=1)  ## original: epochs=30
 
# トレーニングの入力を流用して実際に分類
Y = model.predict_classes(X, batch_size=1)

print("TEST")
print(Y == T)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_5 (Dense)              (None, 1)                 3
# _________________________________________________________________
# activation_5 (Activation)    (None, 1)                 0
# ...
# Total params: 3
# Trainable params: 3
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 4/4 [==============================] - 0s 87ms/step - loss: 0.4976
# Epoch 2/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4734
# Epoch 3/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4528
# Epoch 4/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4364
# Epoch 5/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4231
# Epoch 6/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4115
# Epoch 7/100
# ...

# %% [markdown]
# ----
# ### [try]
# -  AND回路, XOR回路に変更
# ----

# %%
# モジュール読み込み
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.optimizers import SGD
 
# 乱数を固定値で初期化
np.random.seed(1)  ## original: np.random.seed(0)

# シグモイドの単純パーセプトロン作成
model = Sequential()
model.add(Dense(input_dim=2, units=1))
model.add(Activation('sigmoid'))
model.summary()

model.compile(loss='binary_crossentropy', optimizer=SGD(lr=0.1))
 
# トレーニング用入力 X と正解データ T
#X = np.array( [[0,0], [0,1], [1,0], [1,1]] )  # original: OR回路
#T = np.array( [[0], [1], [1], [1]] )
X = np.array( [[0,0], [0,1], [1,0], [1,1]] )   # AND回路
T = np.array( [[0], [0], [0], [1]] )
#X = np.array( [[0,0], [0,1], [1,0], [1,1]] )  # XOR回路
#T = np.array( [[0], [1], [1], [1]] )

 
# トレーニング
model.fit(X, T, epochs=100, batch_size=1)  ## original: epochs=30
 
# トレーニングの入力を流用して実際に分類
Y = model.predict_classes(X, batch_size=1)

print("TEST")
print(Y == T)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_6 (Dense)              (None, 1)                 3
# _________________________________________________________________
# activation_6 (Activation)    (None, 1)                 0
# ...
# Total params: 3
# Trainable params: 3
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 4/4 [==============================] - 0s 96ms/step - loss: 0.7426
# Epoch 2/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.6940
# Epoch 3/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.6544
# Epoch 4/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.6247
# Epoch 5/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.6017
# Epoch 6/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5820
# Epoch 7/100
# ...

# %%
# モジュール読み込み
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.optimizers import SGD
 
# 乱数を固定値で初期化
np.random.seed(1)  ## original: np.random.seed(0)

# シグモイドの単純パーセプトロン作成
model = Sequential()
model.add(Dense(input_dim=2, units=1))
model.add(Activation('sigmoid'))
model.summary()

model.compile(loss='binary_crossentropy', optimizer=SGD(lr=0.1))
 
# トレーニング用入力 X と正解データ T
#X = np.array( [[0,0], [0,1], [1,0], [1,1]] )  # original: OR回路
#T = np.array( [[0], [1], [1], [1]] )
#X = np.array( [[0,0], [0,1], [1,0], [1,1]] )   # AND回路
#T = np.array( [[0], [0], [0], [1]] )
X = np.array( [[0,0], [0,1], [1,0], [1,1]] )  # XOR回路
T = np.array( [[0], [1], [1], [0]] )

 
# トレーニング
model.fit(X, T, epochs=100, batch_size=1)  ## original: epochs=30
 
# トレーニングの入力を流用して実際に分類
Y = model.predict_classes(X, batch_size=1)

print("TEST")
print(Y == T)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_8 (Dense)              (None, 1)                 3
# _________________________________________________________________
# activation_8 (Activation)    (None, 1)                 0
# ...
# Total params: 3
# Trainable params: 3
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 4/4 [==============================] - 0s 104ms/step - loss: 0.7694
# Epoch 2/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.7597
# Epoch 3/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.7522
# Epoch 4/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.7467
# Epoch 5/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.7423
# Epoch 6/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.7388
# Epoch 7/100
# ...

# %% [markdown]
# ----
# ### [try]
# -  OR回路にしてバッチサイズを10に変更
# ----

# %%
# モジュール読み込み
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.optimizers import SGD
 
# 乱数を固定値で初期化
np.random.seed(1)  ## original: np.random.seed(0)

# シグモイドの単純パーセプトロン作成
model = Sequential()
model.add(Dense(input_dim=2, units=1))
model.add(Activation('sigmoid'))
model.summary()

model.compile(loss='binary_crossentropy', optimizer=SGD(lr=0.1))
 
# トレーニング用入力 X と正解データ T
X = np.array( [[0,0], [0,1], [1,0], [1,1]] )  # original: OR回路
T = np.array( [[0], [1], [1], [1]] )
#X = np.array( [[0,0], [0,1], [1,0], [1,1]] )   # AND回路
#T = np.array( [[0], [0], [0], [1]] )
#X = np.array( [[0,0], [0,1], [1,0], [1,1]] )  # XOR回路
#T = np.array( [[0], [1], [1], [0]] )

 
# トレーニング
model.fit(X, T, epochs=100, batch_size=10)  ## original: epochs=30, batch_size=1
 
# トレーニングの入力を流用して実際に分類
Y = model.predict_classes(X, batch_size=10) ## original batch_size=1

print("TEST")
print(Y == T)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_11 (Dense)             (None, 1)                 3
# _________________________________________________________________
# activation_11 (Activation)   (None, 1)                 0
# ...
# Total params: 3
# Trainable params: 3
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 4/4 [==============================] - 0s 118ms/step - loss: 0.4980
# Epoch 2/100
# 4/4 [==============================] - 0s 342us/step - loss: 0.4908
# Epoch 3/100
# 4/4 [==============================] - 0s 371us/step - loss: 0.4841
# Epoch 4/100
# 4/4 [==============================] - 0s 379us/step - loss: 0.4778
# Epoch 5/100
# 4/4 [==============================] - 0s 385us/step - loss: 0.4719
# Epoch 6/100
# 4/4 [==============================] - 0s 558us/step - loss: 0.4662
# Epoch 7/100
# ...

# %% [markdown]
# ----
# ### [try]
# -  エポック数を300に変更しよう
# ----

# %%
# モジュール読み込み
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.optimizers import SGD
 
# 乱数を固定値で初期化
np.random.seed(1)  ## original: np.random.seed(0)

# シグモイドの単純パーセプトロン作成
model = Sequential()
model.add(Dense(input_dim=2, units=1))
model.add(Activation('sigmoid'))
model.summary()

model.compile(loss='binary_crossentropy', optimizer=SGD(lr=0.1))
 
# トレーニング用入力 X と正解データ T
X = np.array( [[0,0], [0,1], [1,0], [1,1]] )  # original: OR回路
T = np.array( [[0], [1], [1], [1]] )
#X = np.array( [[0,0], [0,1], [1,0], [1,1]] )   # AND回路
#T = np.array( [[0], [0], [0], [1]] )
#X = np.array( [[0,0], [0,1], [1,0], [1,1]] )  # XOR回路
#T = np.array( [[0], [1], [1], [0]] )

 
# トレーニング
model.fit(X, T, epochs=300, batch_size=10)  ## original: epochs=30, batch_size=1
 
# トレーニングの入力を流用して実際に分類
Y = model.predict_classes(X, batch_size=10) ## original batch_size=1

print("TEST")
print(Y == T)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_12 (Dense)             (None, 1)                 3
# _________________________________________________________________
# activation_12 (Activation)   (None, 1)                 0
# ...
# Total params: 3
# Trainable params: 3
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/300
# 4/4 [==============================] - 0s 123ms/step - loss: 0.4980
# Epoch 2/300
# 4/4 [==============================] - 0s 339us/step - loss: 0.4908
# Epoch 3/300
# 4/4 [==============================] - 0s 417us/step - loss: 0.4841
# Epoch 4/300
# 4/4 [==============================] - 0s 368us/step - loss: 0.4778
# Epoch 5/300
# 4/4 [==============================] - 0s 402us/step - loss: 0.4719
# Epoch 6/300
# 4/4 [==============================] - 0s 541us/step - loss: 0.4662
# Epoch 7/300
# ...
