# %% [markdown]
# # keras

# %% [markdown]
# ## 分類 (mnist)

# %%
# 必要なライブラリのインポート
import sys, os
sys.path.append(os.pardir)  # 親ディレクトリのファイルをインポートするための設定
import keras
import matplotlib.pyplot as plt
from data.mnist import load_mnist

## 【レポート提出者変更】
# %matplotlib inline

(x_train, d_train), (x_test, d_test) = load_mnist(normalize=True, one_hot_label=True)

# 必要なライブラリのインポート、最適化手法はAdamを使う
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.optimizers import Adam

# モデル作成
model = Sequential()
model.add(Dense(512, activation='relu', input_shape=(784,)))
model.add(Dropout(0.2))
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(10, activation='softmax'))
model.summary()

# バッチサイズ、エポック数
batch_size = 128
epochs = 20

model.compile(loss='categorical_crossentropy', 
              optimizer=Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False), 
              metrics=['accuracy'])

history = model.fit(x_train, d_train, batch_size=batch_size, epochs=epochs, verbose=1, validation_data=(x_test, d_test))
loss = model.evaluate(x_test, d_test, verbose=0)
print('Test loss:', loss[0])
print('Test accuracy:', loss[1])
#Accuracy
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
# plt.ylim(0, 1.0)
plt.show()
# Out:
# Using TensorFlow backend.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 512)               401920
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 669,706
# Trainable params: 669,706
# Non-trainable params: 0
# _________________________________________________________________
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/20
# 60000/60000 [==============================] - 10s 174us/step - loss: 0.2523 - acc: 0.9238 - val_loss: 0.0984 - val_acc: 0.9691
# Epoch 2/20
# 60000/60000 [==============================] - 9s 150us/step - loss: 0.1023 - acc: 0.9680 - val_loss: 0.0813 - val_acc: 0.9737
# Epoch 3/20
# 60000/60000 [==============================] - 9s 151us/step - loss: 0.0741 - acc: 0.9766 - val_loss: 0.0798 - val_acc: 0.9769
# Epoch 4/20
# 60000/60000 [==============================] - 9s 151us/step - loss: 0.0565 - acc: 0.9820 - val_loss: 0.0653 - val_acc: 0.9802
# Epoch 5/20
# 60000/60000 [==============================] - 9s 150us/step - loss: 0.0464 - acc: 0.9844 - val_loss: 0.0656 - val_acc: 0.9797
# Epoch 6/20
# 60000/60000 [==============================] - 9s 151us/step - loss: 0.0387 - acc: 0.9874 - val_loss: 0.0647 - val_acc: 0.9815
# Epoch 7/20
# 60000/60000 [==============================] - 9s 156us/step - loss: 0.0312 - acc: 0.9895 - val_loss: 0.0696 - val_acc: 0.9804
# Epoch 8/20
# 60000/60000 [==============================] - 9s 155us/step - loss: 0.0310 - acc: 0.9900 - val_loss: 0.0774 - val_acc: 0.9784
# Epoch 9/20
# 60000/60000 [==============================] - 9s 155us/step - loss: 0.0270 - acc: 0.9911 - val_loss: 0.0725 - val_acc: 0.9806
# Epoch 10/20
# 60000/60000 [==============================] - 9s 157us/step - loss: 0.0264 - acc: 0.9911 - val_loss: 0.0741 - val_acc: 0.9807
# Epoch 11/20
# 60000/60000 [==============================] - 9s 154us/step - loss: 0.0239 - acc: 0.9922 - val_loss: 0.0784 - val_acc: 0.9795
# Epoch 12/20
# 60000/60000 [==============================] - 9s 154us/step - loss: 0.0224 - acc: 0.9924 - val_loss: 0.0804 - val_acc: 0.9818
# Epoch 13/20
# 60000/60000 [==============================] - 9s 155us/step - loss: 0.0218 - acc: 0.9928 - val_loss: 0.0842 - val_acc: 0.9801
# Epoch 14/20
# 60000/60000 [==============================] - 9s 154us/step - loss: 0.0182 - acc: 0.9940 - val_loss: 0.0819 - val_acc: 0.9793
# Epoch 15/20
# 60000/60000 [==============================] - 9s 155us/step - loss: 0.0166 - acc: 0.9941 - val_loss: 0.0705 - val_acc: 0.9836
# Epoch 16/20
# 60000/60000 [==============================] - 9s 157us/step - loss: 0.0186 - acc: 0.9942 - val_loss: 0.0746 - val_acc: 0.9827
# Epoch 17/20
# 60000/60000 [==============================] - 9s 155us/step - loss: 0.0156 - acc: 0.9945 - val_loss: 0.0818 - val_acc: 0.9817
# Epoch 18/20
# 60000/60000 [==============================] - 9s 156us/step - loss: 0.0160 - acc: 0.9952 - val_loss: 0.0777 - val_acc: 0.9826
# Epoch 19/20
# 60000/60000 [==============================] - 9s 158us/step - loss: 0.0179 - acc: 0.9944 - val_loss: 0.0739 - val_acc: 0.9839
# Epoch 20/20
# 60000/60000 [==============================] - 9s 156us/step - loss: 0.0141 - acc: 0.9957 - val_loss: 0.0765 - val_acc: 0.9812
# Test loss: 0.07651409786236427
# Test accuracy: 0.9812

# %% [markdown]
# -----
# ### [try]
# -  load_mnistのone_hot_labelをFalseに変更しよう (error)
# -----

# %%
# 必要なライブラリのインポート
import sys, os
sys.path.append(os.pardir)  # 親ディレクトリのファイルをインポートするための設定
import keras
import matplotlib.pyplot as plt
from data.mnist import load_mnist

## 【レポート提出者変更】
# %matplotlib inline

(x_train, d_train), (x_test, d_test) = load_mnist(normalize=True, one_hot_label=False)  ## 【レポート提出者変更】

# 必要なライブラリのインポート、最適化手法はAdamを使う
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.optimizers import Adam

# モデル作成
model = Sequential()
model.add(Dense(512, activation='relu', input_shape=(784,)))
model.add(Dropout(0.2))
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(10, activation='softmax'))
model.summary()

# バッチサイズ、エポック数
batch_size = 128
epochs = 20

## 【レポート提出者変更】
model.compile(loss='categorical_crossentropy', 
              optimizer=Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False), 
              metrics=['accuracy'])

history = model.fit(x_train, d_train, batch_size=batch_size, epochs=epochs, verbose=1, validation_data=(x_test, d_test))
loss = model.evaluate(x_test, d_test, verbose=0)
print('Test loss:', loss[0])
print('Test accuracy:', loss[1])
#Accuracy
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
# plt.ylim(0, 1.0)
plt.show()
# Out:
# Using TensorFlow backend.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 512)               401920
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 669,706
# Trainable params: 669,706
# Non-trainable params: 0
# _________________________________________________________________
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-a9c87264905b> in <module>
#      34               metrics=['accuracy'])
#      35
# ---> 36 history = model.fit(x_train, d_train, batch_size=batch_size, epochs=epochs, verbose=1, validation_data=(x_test, d_test))
#      37 loss = model.evaluate(x_test, d_test, verbose=0)
#      38 print('Test loss:', loss[0])
#
# ~/.anyenv/envs/pyenv/versions/anaconda3-4.4.0/lib/python3.6/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#     950             sample_weight=sample_weight,
#     951             class_weight=class_weight,
# --> 952             batch_size=batch_size)
#     953         # Prepare validation data.
#     954         do_validation = False
#
# ~/.anyenv/envs/pyenv/versions/anaconda3-4.4.0/lib/python3.6/site-packages/keras/engine/training.py in _standardize_user_data(self, x, y, sample_weight, class_weight, check_array_lengths, batch_size)
#     787                 feed_output_shapes,
#     788                 check_batch_axis=False,  # Don't enforce the batch size.
# --> 789                 exception_prefix='target')
#     790
#     791             # Generate sample-wise weight values given the `sample_weight` and
#
# ~/.anyenv/envs/pyenv/versions/anaconda3-4.4.0/lib/python3.6/site-packages/keras/engine/training_utils.py in standardize_input_data(data, names, shapes, check_batch_axis, exception_prefix)
#     136                             ': expected ' + names[i] + ' to have shape ' +
#     137                             str(shape) + ' but got array with shape ' +
# --> 138                             str(data_shape))
#     139     return data
#     140
#
# ValueError: Error when checking target: expected dense_3 to have shape (10,) but got array with shape (1,)

# %% [markdown]
# -----
# ### [try]
# -  誤差関数をsparse_categorical_crossentropyに変更しよう
# -----

# %%
# 必要なライブラリのインポート
import sys, os
sys.path.append(os.pardir)  # 親ディレクトリのファイルをインポートするための設定
import keras
import matplotlib.pyplot as plt
from data.mnist import load_mnist

## 【レポート提出者変更】
# %matplotlib inline

(x_train, d_train), (x_test, d_test) = load_mnist(normalize=True, one_hot_label=False)  ## 【レポート提出者変更】

# 必要なライブラリのインポート、最適化手法はAdamを使う
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.optimizers import Adam

# モデル作成
model = Sequential()
model.add(Dense(512, activation='relu', input_shape=(784,)))
model.add(Dropout(0.2))
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(10, activation='softmax'))
model.summary()

# バッチサイズ、エポック数
batch_size = 128
epochs = 20

## 【レポート提出者変更】
## categorical_crossentropy -> sparse_categorical_crossentropy に変更
##
#model.compile(loss='categorical_crossentropy', 
#              optimizer=Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False), 
#              metrics=['accuracy'])
model.compile(loss='sparse_categorical_crossentropy', 
              optimizer=Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False), 
              metrics=['accuracy'])

history = model.fit(x_train, d_train, batch_size=batch_size, epochs=epochs, verbose=1, validation_data=(x_test, d_test))
loss = model.evaluate(x_test, d_test, verbose=0)
print('Test loss:', loss[0])
print('Test accuracy:', loss[1])
#Accuracy
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
# plt.ylim(0, 1.0)
plt.show()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_4 (Dense)              (None, 512)               401920
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 669,706
# Trainable params: 669,706
# Non-trainable params: 0
# _________________________________________________________________
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/20
# 60000/60000 [==============================] - 11s 177us/step - loss: 0.2521 - acc: 0.9233 - val_loss: 0.1071 - val_acc: 0.9653
# Epoch 2/20
# 60000/60000 [==============================] - 10s 162us/step - loss: 0.1012 - acc: 0.9693 - val_loss: 0.0807 - val_acc: 0.9757
# Epoch 3/20
# 60000/60000 [==============================] - 9s 152us/step - loss: 0.0708 - acc: 0.9776 - val_loss: 0.0729 - val_acc: 0.9771
# Epoch 4/20
# 60000/60000 [==============================] - 9s 153us/step - loss: 0.0569 - acc: 0.9812 - val_loss: 0.0657 - val_acc: 0.9804
# Epoch 5/20
# 60000/60000 [==============================] - 9s 148us/step - loss: 0.0444 - acc: 0.9853 - val_loss: 0.0644 - val_acc: 0.9797
# Epoch 6/20
# 60000/60000 [==============================] - 9s 154us/step - loss: 0.0384 - acc: 0.9877 - val_loss: 0.0689 - val_acc: 0.9796
# Epoch 7/20
# 60000/60000 [==============================] - 9s 151us/step - loss: 0.0364 - acc: 0.9879 - val_loss: 0.0661 - val_acc: 0.9821
# Epoch 8/20
# 60000/60000 [==============================] - 9s 146us/step - loss: 0.0318 - acc: 0.9895 - val_loss: 0.0599 - val_acc: 0.9832
# Epoch 9/20
# 60000/60000 [==============================] - 9s 149us/step - loss: 0.0246 - acc: 0.9918 - val_loss: 0.0625 - val_acc: 0.9833
# Epoch 10/20
# 60000/60000 [==============================] - 9s 156us/step - loss: 0.0268 - acc: 0.9909 - val_loss: 0.0665 - val_acc: 0.9812
# Epoch 11/20
# 60000/60000 [==============================] - 9s 154us/step - loss: 0.0225 - acc: 0.9924 - val_loss: 0.0862 - val_acc: 0.9792
# Epoch 12/20
# 60000/60000 [==============================] - 9s 151us/step - loss: 0.0236 - acc: 0.9919 - val_loss: 0.0738 - val_acc: 0.9818
# Epoch 13/20
# 60000/60000 [==============================] - 9s 152us/step - loss: 0.0192 - acc: 0.9935 - val_loss: 0.0827 - val_acc: 0.9802
# Epoch 14/20
# 60000/60000 [==============================] - 9s 151us/step - loss: 0.0219 - acc: 0.9923 - val_loss: 0.0653 - val_acc: 0.9845
# Epoch 15/20
# 60000/60000 [==============================] - 9s 154us/step - loss: 0.0193 - acc: 0.9935 - val_loss: 0.0729 - val_acc: 0.9823
# Epoch 16/20
# 60000/60000 [==============================] - 9s 153us/step - loss: 0.0174 - acc: 0.9943 - val_loss: 0.0639 - val_acc: 0.9842
# Epoch 17/20
# 60000/60000 [==============================] - 9s 155us/step - loss: 0.0142 - acc: 0.9953 - val_loss: 0.0659 - val_acc: 0.9837
# Epoch 18/20
# 60000/60000 [==============================] - 9s 151us/step - loss: 0.0175 - acc: 0.9941 - val_loss: 0.0709 - val_acc: 0.9829
# Epoch 19/20
# 60000/60000 [==============================] - 9s 151us/step - loss: 0.0157 - acc: 0.9946 - val_loss: 0.0697 - val_acc: 0.9842
# Epoch 20/20
# 60000/60000 [==============================] - 9s 149us/step - loss: 0.0157 - acc: 0.9947 - val_loss: 0.0674 - val_acc: 0.9851
# Test loss: 0.06737037362464343
# Test accuracy: 0.9851

# %% [markdown]
# -----
# ### [try]
# -  Adamの引数の値を変更しよう
# -----

# %%
# 必要なライブラリのインポート
import sys, os
sys.path.append(os.pardir)  # 親ディレクトリのファイルをインポートするための設定
import keras
import matplotlib.pyplot as plt
from data.mnist import load_mnist

## 【レポート提出者変更】
# %matplotlib inline

(x_train, d_train), (x_test, d_test) = load_mnist(normalize=True, one_hot_label=True)

# 必要なライブラリのインポート、最適化手法はAdamを使う
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.optimizers import Adam

# モデル作成
model = Sequential()
model.add(Dense(512, activation='relu', input_shape=(784,)))
model.add(Dropout(0.2))
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(10, activation='softmax'))
model.summary()

# バッチサイズ、エポック数
batch_size = 128
epochs = 20

#model.compile(loss='categorical_crossentropy', 
#              optimizer=Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False), 
#              metrics=['accuracy'])
model.compile(loss='categorical_crossentropy', 
              optimizer=Adam(lr=0.01, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False), 
              metrics=['accuracy'])

history = model.fit(x_train, d_train, batch_size=batch_size, epochs=epochs, verbose=1, validation_data=(x_test, d_test))
loss = model.evaluate(x_test, d_test, verbose=0)
print('Test loss:', loss[0])
print('Test accuracy:', loss[1])
#Accuracy
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
# plt.ylim(0, 1.0)
plt.show()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_7 (Dense)              (None, 512)               401920
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_9 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 669,706
# Trainable params: 669,706
# Non-trainable params: 0
# _________________________________________________________________
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/20
# 60000/60000 [==============================] - 9s 156us/step - loss: 0.3245 - acc: 0.9071 - val_loss: 0.1748 - val_acc: 0.9526
# Epoch 2/20
# 60000/60000 [==============================] - 9s 144us/step - loss: 0.2392 - acc: 0.9354 - val_loss: 0.1635 - val_acc: 0.9572
# Epoch 3/20
# 60000/60000 [==============================] - 9s 146us/step - loss: 0.2311 - acc: 0.9410 - val_loss: 0.1776 - val_acc: 0.9569
# Epoch 4/20
# 60000/60000 [==============================] - 9s 144us/step - loss: 0.2140 - acc: 0.9466 - val_loss: 0.1756 - val_acc: 0.9571
# Epoch 5/20
# 60000/60000 [==============================] - 9s 144us/step - loss: 0.2012 - acc: 0.9503 - val_loss: 0.1629 - val_acc: 0.9595
# Epoch 6/20
# 60000/60000 [==============================] - 9s 147us/step - loss: 0.1985 - acc: 0.9512 - val_loss: 0.1456 - val_acc: 0.9645
# Epoch 7/20
# 60000/60000 [==============================] - 9s 145us/step - loss: 0.1861 - acc: 0.9538 - val_loss: 0.1516 - val_acc: 0.9634
# Epoch 8/20
# 60000/60000 [==============================] - 9s 146us/step - loss: 0.1955 - acc: 0.9538 - val_loss: 0.1630 - val_acc: 0.9612
# Epoch 9/20
# 60000/60000 [==============================] - 9s 145us/step - loss: 0.1866 - acc: 0.9556 - val_loss: 0.1382 - val_acc: 0.9674
# Epoch 10/20
# 60000/60000 [==============================] - 9s 146us/step - loss: 0.1917 - acc: 0.9556 - val_loss: 0.1745 - val_acc: 0.9612
# Epoch 11/20
# 60000/60000 [==============================] - 9s 147us/step - loss: 0.1839 - acc: 0.9581 - val_loss: 0.1538 - val_acc: 0.9666
# Epoch 12/20
# 60000/60000 [==============================] - 9s 147us/step - loss: 0.1699 - acc: 0.9603 - val_loss: 0.1345 - val_acc: 0.9666
# Epoch 13/20
# 60000/60000 [==============================] - 9s 149us/step - loss: 0.1792 - acc: 0.9599 - val_loss: 0.1921 - val_acc: 0.9657
# Epoch 14/20
# 60000/60000 [==============================] - 9s 148us/step - loss: 0.1865 - acc: 0.9585 - val_loss: 0.1512 - val_acc: 0.9655
# Epoch 15/20
# 60000/60000 [==============================] - 9s 151us/step - loss: 0.1859 - acc: 0.9583 - val_loss: 0.1812 - val_acc: 0.9599
# Epoch 16/20
# 60000/60000 [==============================] - 9s 149us/step - loss: 0.1794 - acc: 0.9598 - val_loss: 0.1638 - val_acc: 0.9673
# Epoch 17/20
# 60000/60000 [==============================] - 9s 150us/step - loss: 0.1653 - acc: 0.9618 - val_loss: 0.1504 - val_acc: 0.9704
# Epoch 18/20
# 60000/60000 [==============================] - 9s 150us/step - loss: 0.1650 - acc: 0.9622 - val_loss: 0.1674 - val_acc: 0.9655
# Epoch 19/20
# 60000/60000 [==============================] - 9s 153us/step - loss: 0.1600 - acc: 0.9632 - val_loss: 0.1547 - val_acc: 0.9697
# Epoch 20/20
# 60000/60000 [==============================] - 9s 153us/step - loss: 0.1610 - acc: 0.9641 - val_loss: 0.1747 - val_acc: 0.9653
# Test loss: 0.17474257342660895
# Test accuracy: 0.9653
