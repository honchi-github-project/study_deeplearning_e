# %% [markdown]
# # keras

# %% [markdown]
# ## 線形回帰

# %%
import numpy as np
import matplotlib.pyplot as plt

## 【レポート提出者変更】
# %matplotlib inline

iters_num = 1000
plot_interval = 10

x = np.linspace(-1, 1, 200)
np.random.shuffle(x)
d = 0.5 * x + 2 + np.random.normal(0, 0.05, (200,))

from keras.models import Sequential
from keras.layers import Dense

# モデルを作成
model = Sequential()
model.add(Dense(input_dim=1, output_dim=1))

# モデルを表示
model.summary()

# モデルのコンパイル
model.compile(loss='mse', optimizer='sgd')

# train
for i in range(iters_num):
    loss = model.train_on_batch(x, d)
    if (i+1) % plot_interval == 0:
        print('Generation: ' + str(i+1) + '. 誤差 = ' + str(loss))

W, b = model.layers[0].get_weights()
print('W:', W)
print('b:', b)

y = model.predict(x)
plt.scatter(x, d)
plt.plot(x, y)
plt.show()
# Out:
# Using TensorFlow backend.
# /Users/honchi/.anyenv/envs/pyenv/versions/anaconda3-4.4.0/lib/python3.6/site-packages/ipykernel_launcher.py:19: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(input_dim=1, units=1)`
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 1)                 2
# =================================================================
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
# _________________________________________________________________
# Generation: 10. 誤差 = 3.566492
# Generation: 20. 誤差 = 2.5433004
# Generation: 30. 誤差 = 1.8398147
# Generation: 40. 誤差 = 1.352345
# Generation: 50. 誤差 = 1.0113415
# Generation: 60. 誤差 = 0.7700874
# Generation: 70. 誤差 = 0.5971454
# Generation: 80. 誤差 = 0.47131026
# Generation: 90. 誤差 = 0.3782361
# Generation: 100. 誤差 = 0.30817914
# Generation: 110. 誤差 = 0.25448978
# Generation: 120. 誤差 = 0.21260196
# Generation: 130. 誤差 = 0.17935707
# Generation: 140. 誤差 = 0.15254956
# Generation: 150. 誤差 = 0.13062279
# Generation: 160. 誤差 = 0.112463824
# Generation: 170. 誤差 = 0.097265214
# Generation: 180. 誤差 = 0.08443172
# Generation: 190. 誤差 = 0.07351682
# Generation: 200. 誤差 = 0.06417943
# Generation: 210. 誤差 = 0.05615438
# Generation: 220. 誤差 = 0.049231883
# Generation: 230. 誤差 = 0.043243255
# Generation: 240. 誤差 = 0.03805089
# Generation: 250. 誤差 = 0.033541065
# Generation: 260. 誤差 = 0.02961879
# Generation: 270. 誤差 = 0.026203988
# Generation: 280. 誤差 = 0.023228597
# Generation: 290. 誤差 = 0.020634513
# Generation: 300. 誤差 = 0.018371793
# Generation: 310. 誤差 = 0.016397389
# Generation: 320. 誤差 = 0.0146740945
# Generation: 330. 誤差 = 0.013169663
# Generation: 340. 誤差 = 0.011856066
# Generation: 350. 誤差 = 0.010708971
# Generation: 360. 誤差 = 0.009707179
# Generation: 370. 誤差 = 0.008832208
# Generation: 380. 誤差 = 0.008067971
# Generation: 390. 誤差 = 0.0074004238
# Generation: 400. 誤差 = 0.0068173134
# Generation: 410. 誤差 = 0.006307949
# Generation: 420. 誤差 = 0.005862993
# Generation: 430. 誤差 = 0.0054742955
# Generation: 440. 誤差 = 0.0051347376
# Generation: 450. 誤差 = 0.004838107
# Generation: 460. 誤差 = 0.004578978
# Generation: 470. 誤差 = 0.0043526017
# Generation: 480. 誤差 = 0.0041548437
# Generation: 490. 誤差 = 0.003982081
# Generation: 500. 誤差 = 0.0038311589
# Generation: 510. 誤差 = 0.0036993113
# Generation: 520. 誤差 = 0.003584128
# Generation: 530. 誤差 = 0.0034835069
# Generation: 540. 誤差 = 0.003395601
# Generation: 550. 誤差 = 0.0033188097
# Generation: 560. 誤差 = 0.0032517212
# Generation: 570. 誤差 = 0.0031931156
# Generation: 580. 誤差 = 0.0031419152
# Generation: 590. 誤差 = 0.003097188
# Generation: 600. 誤差 = 0.0030581134
# Generation: 610. 誤差 = 0.003023978
# Generation: 620. 誤差 = 0.0029941588
# Generation: 630. 誤差 = 0.0029681078
# Generation: 640. 誤差 = 0.0029453493
# Generation: 650. 誤差 = 0.0029254672
# Generation: 660. 誤差 = 0.0029080992
# Generation: 670. 誤差 = 0.0028929256
# Generation: 680. 誤差 = 0.0028796704
# Generation: 690. 誤差 = 0.0028680908
# Generation: 700. 誤差 = 0.0028579745
# Generation: 710. 誤差 = 0.0028491365
# Generation: 720. 誤差 = 0.0028414165
# Generation: 730. 誤差 = 0.0028346723
# Generation: 740. 誤差 = 0.0028287787
# Generation: 750. 誤差 = 0.0028236315
# Generation: 760. 誤差 = 0.0028191346
# Generation: 770. 誤差 = 0.0028152065
# Generation: 780. 誤差 = 0.002811774
# Generation: 790. 誤差 = 0.0028087753
# Generation: 800. 誤差 = 0.0028061569
# Generation: 810. 誤差 = 0.0028038674
# Generation: 820. 誤差 = 0.0028018684
# Generation: 830. 誤差 = 0.0028001228
# Generation: 840. 誤差 = 0.0027985957
# Generation: 850. 誤差 = 0.0027972655
# Generation: 860. 誤差 = 0.002796101
# Generation: 870. 誤差 = 0.0027950832
# Generation: 880. 誤差 = 0.0027941943
# Generation: 890. 誤差 = 0.0027934187
# Generation: 900. 誤差 = 0.0027927398
# Generation: 910. 誤差 = 0.002792148
# Generation: 920. 誤差 = 0.0027916303
# Generation: 930. 誤差 = 0.0027911777
# Generation: 940. 誤差 = 0.002790783
# Generation: 950. 誤差 = 0.0027904392
# Generation: 960. 誤差 = 0.0027901374
# Generation: 970. 誤差 = 0.0027898739
# Generation: 980. 誤差 = 0.002789643
# Generation: 990. 誤差 = 0.0027894424
# Generation: 1000. 誤差 = 0.0027892673
# W: [[0.49656883]]
# b: [1.9999499]
